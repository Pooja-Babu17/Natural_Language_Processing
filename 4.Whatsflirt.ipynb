# %%
import numpy as np
import pandas as pd
import time
import datetime
import matplotlib.pyplot as plt
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from wordcloud import WordCloud, STOPWORDS 
import seaborn as sns
from nltk.corpus import stopwords

# %%
df = pd.read_csv("mabel.txt", header=None, encoding='utf-8', on_bad_lines='skip')
df
# Out:
#            0                                                  1
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 14  05/12/19                      1:48 pm - Mabel Infoziant: ok
# 15  05/12/19   1:48 pm - Mabel Infoziant: send the details o...
# 16  05/12/19   1:49 pm - AR❤: Sure mam. Soon I will share de...
# 17  05/12/19   2:00 pm - AR❤: I have read the Abstract mam. ...
# 18  05/12/19   2:04 pm - Mabel Infoziant: I think Vignesh ha...
# 19  05/12/19   2:04 pm - Mabel Infoziant: I have sent the ab...
# 20  05/12/19                              2:06 pm - AR❤: Ok mam
# 21  05/12/19   2:07 pm - AR❤: I have read both the abstract ...
# 22  05/12/19   4:44 pm - Mabel Infoziant: Yes we need to ya ...
# 23  05/12/19                           4:48 pm - AR❤: Sure mam.
# 24  05/12/19                   8:07 pm - AR❤: Shall I call mam?
# 25  08/12/19   10:45 pm - Mabel Infoziant: Hi I was at churc...
# 26  08/12/19                         11:52 pm - AR❤: It's k mam
# 27  08/12/19   11:55 pm - AR❤: Just to know the tomorrow pla...
# 28  09/12/19    12:09 pm - AR❤: Mam can u send Vignesh number??
# 29  09/12/19   12:13 pm - Mabel Infoziant: Vignesh ML Infozi...
# 30  09/12/19   12:23 pm - Mabel Infoziant: I was in a meetin...
# 31  09/12/19                    12:25 pm - AR❤: Can I cal u mam
# 32  09/12/19   12:26 pm - AR❤: Waiting for u r finalization ...
# 33  09/12/19   12:26 pm - AR❤: If we finiliaze I can work wi...
# 34  09/12/19   12:28 pm - AR❤: So what ever may be ..if you ...
# 35  09/12/19           12:28 pm - AR❤: You deleted this message
# 36  09/12/19                     12:29 pm - AR❤: Do the needful
# 37  09/12/19   12:41 pm - Mabel Infoziant: No ma please hold...
# 38  09/12/19                     12:42 pm - AR❤: Ok mam thank u
# 39  10/12/19   7:59 am - Mabel Infoziant: Ramisha we need to...
# 40  10/12/19   8:00 am - Mabel Infoziant: Be ready to discus...
# 41  10/12/19                            8:55 am - AR❤: Okay mam
# 42  12/12/19                      2:26 pm - Mabel Infoziant: ok
# 43  15/12/19                     8:22 pm - AR❤: Mam are u free?
# 44  15/12/19   8:40 pm - Mabel Infoziant: Am at church can c...
# 45  15/12/19   8:40 pm - AR❤: Kk mam. I will ask Arun brothe...
# 46  18/12/19                              3:09 pm - AR❤: Hi mam
# 47  18/12/19                    3:09 pm - AR❤: Any updates mam?
# 48  18/12/19   3:11 pm - Mabel Infoziant: U might have to st...
# 49  18/12/19   3:11 pm - Mabel Infoziant: There is one proje...
# 50  18/12/19                            3:12 pm - AR❤: Kk mam👍🏻

# %%
df= df.drop(0)
df.columns=['Date', 'Chat']
Message= df["Chat"].str.split("-", n = 1, expand = True) 
df['Date']=df['Date'].str.replace(",","") 
df['Time']=Message[0]
df['Text']=Message[1]
Message1= df["Text"].str.split(":", n = 1, expand = True) 
df['Text']=Message1[1]
df['Name']=Message1[0]
df=df.drop(columns=['Chat'])
df['Text']=df['Text'].str.lower()
df=df.dropna()

# %%
dataset=df
dataset
# Out:
#         Date        Time                                               Text  \
# 1   05/12/19    1:42 pm                      hi this is mabel we just spoke
# 2   05/12/19    1:42 pm                               what’s your full name
# 3   05/12/19    1:42 pm                                      ramisha rani k
# 4   05/12/19    1:42 pm                                                  ok
# 5   05/12/19    1:42 pm                              ramisharanik@gmail.com
# 6   05/12/19    1:43 pm                                      your email id?
# 7   05/12/19    1:43 pm                                             yes mam
# 8   05/12/19    1:43 pm      i will send 2 abstracts for u to start working
# 9   05/12/19    1:43 pm                                            yeah mam
# 10  05/12/19    1:43 pm                    give me the list that u have too
# 11  05/12/19    1:43 pm    send me cbe office address and phone number i...
# 12  05/12/19    1:44 pm     yeah mam within evening i will forward you mam.
# 13  05/12/19    1:45 pm    tomorrow i have to visit the office.yet not i...
# 14  05/12/19    1:48 pm                                                  ok
# 15  05/12/19    1:48 pm    send the details of office location once u ge...
# 16  05/12/19    1:49 pm    sure mam. soon i will share details with you mam
# 17  05/12/19    2:00 pm    i have read the abstract mam. we can do mam. ...
# 18  05/12/19    2:04 pm    i think vignesh has the data set will ask him...
# 19  05/12/19    2:04 pm                           i have sent the abstracts
# 20  05/12/19    2:06 pm                                              ok mam
# 21  05/12/19    2:07 pm    i have read both the abstract mam. we can do ...
# 22  05/12/19    4:44 pm    yes we need to ya about amount and all other ...
# 23  05/12/19    4:48 pm                                           sure mam.
# 24  05/12/19    8:07 pm                                   shall i call mam?
# 25  08/12/19   10:45 pm          hi i was at church couldn’t take your call
# 26  08/12/19   11:52 pm                                          it's k mam
# 27  08/12/19   11:55 pm    just to know the tomorrow plan mam.will see t...
# 28  09/12/19   12:09 pm                     mam can u send vignesh number??
# 29  09/12/19   12:13 pm            vignesh ml infoziant.vcf (file attached)
# 30  09/12/19   12:23 pm                            i was in a meeting sorry
# 31  09/12/19   12:25 pm                                     can i cal u mam
# 32  09/12/19   12:26 pm    waiting for u r finalization of rates for our...
# 33  09/12/19   12:26 pm    if we finiliaze i can work with full involvem...
# 34  09/12/19   12:28 pm    so what ever may be ..if you think your are c...
# 35  09/12/19   12:28 pm                            you deleted this message
# 36  09/12/19   12:29 pm                                      do the needful
# 37  09/12/19   12:41 pm    no ma please hold i am in a hot meeting with ...
# 38  09/12/19   12:42 pm                                      ok mam thank u
# 39  10/12/19    7:59 am    ramisha we need to talk today i will call u a...
# 40  10/12/19    8:00 am      be ready to discuss about the ml titles u have
# 41  10/12/19    8:55 am                                            okay mam
# 42  12/12/19    2:26 pm                                                  ok
# 43  15/12/19    8:22 pm                                     mam are u free?
# 44  15/12/19    8:40 pm    am at church can call very late or tomorrow only
# 45  15/12/19    8:40 pm    kk mam. i will ask arun brother. small doubt ...
# 46  18/12/19    3:09 pm                                              hi mam
# 47  18/12/19    3:09 pm                                    any updates mam?
# 48  18/12/19    3:11 pm      u might have to start on the whatsapp analysis
# 49  18/12/19    3:11 pm             there is one project that got committed
# 50  18/12/19    3:12 pm                                            kk mam👍🏻
#
#                 Name
# 1    Mabel Infoziant
# 2    Mabel Infoziant
# 3                AR❤
# 4    Mabel Infoziant
# 5    Mabel Infoziant
# 6    Mabel Infoziant
# 7                AR❤
# 8    Mabel Infoziant
# 9                AR❤
# 10   Mabel Infoziant
# 11   Mabel Infoziant
# 12               AR❤
# 13               AR❤
# 14   Mabel Infoziant
# 15   Mabel Infoziant
# 16               AR❤
# 17               AR❤
# 18   Mabel Infoziant
# 19   Mabel Infoziant
# 20               AR❤
# 21               AR❤
# 22   Mabel Infoziant
# 23               AR❤
# 24               AR❤
# 25   Mabel Infoziant
# 26               AR❤
# 27               AR❤
# 28               AR❤
# 29   Mabel Infoziant
# 30   Mabel Infoziant
# 31               AR❤
# 32               AR❤
# 33               AR❤
# 34               AR❤
# 35               AR❤
# 36               AR❤
# 37   Mabel Infoziant
# 38               AR❤
# 39   Mabel Infoziant
# 40   Mabel Infoziant
# 41               AR❤
# 42   Mabel Infoziant
# 43               AR❤
# 44   Mabel Infoziant
# 45               AR❤
# 46               AR❤
# 47               AR❤
# 48   Mabel Infoziant
# 49   Mabel Infoziant
# 50               AR❤

# %%
def flirt_analysis(dataset):
    flirt_words = ['Sweetheart','kiss', 'hug', 'date', 'cute', 'beautiful', 'sexy', 'hot', 'adorable', 'darling',
                   'love','romantic']

    result = []
    Talker_chat = dataset[dataset['Name'] == dataset['Name'].value_counts().idxmax()]
    Less_chat = dataset[dataset['Name'] == dataset['Name'].value_counts().idxmin()]

    unique_Frequency_Talker = Talker_chat['Text'].str.split(' ', expand=True).stack().value_counts()
    unique_Frequency_Lesser = Less_chat['Text'].str.split(' ', expand=True).stack().value_counts()

    Talker_Filter_list = unique_Frequency_Talker[unique_Frequency_Talker.index.isin(flirt_words)]
    Less_Filter_list = unique_Frequency_Lesser[unique_Frequency_Lesser.index.isin(flirt_words)]

    if not Talker_Filter_list.empty:
        Talker_Filter_list['Flirt_Frequency'] = (Talker_Filter_list / len(flirt_words)) * 100
        Talker_out = Talker_Filter_list['Flirt_Frequency'].sum() / Talker_Filter_list.shape[0]
        result.append(Talker_out)

    if not Less_Filter_list.empty:
        Less_Filter_list['Flirt_Frequency'] = (Less_Filter_list / len(flirt_words)) * 100
        Less_out = Less_Filter_list['Flirt_Frequency'].sum() / Less_Filter_list.shape[0]
        result.append(Less_out)

    return result

# %%
output = flirt_analysis(dataset)


if output:
    talkative_person = dataset['Name'].value_counts().idxmax()
    print("Talkative Person:", talkative_person)
    print("Flirting Percentage of", talkative_person, ":", output[0], "%")

    if len(output) > 1:
        less_talkative_person = dataset['Name'].value_counts().idxmin()
        print("Less Talkative Person:", less_talkative_person)
        print("Flirting Percentage of", less_talkative_person, ":", output[1], "%")
else:
    print("No flirt words found for any person.")
# Out:
# Talkative Person:  AR❤
# Flirting Percentage of  AR❤ : 4.166666666666666 %

# %%
most_active_date =dataset['Date'].value_counts().idxmax()
print("Most Active Date:", most_active_date)


week_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
date_obj = datetime.datetime.strptime(most_active_date, "%d/%m/%y")
active_day_of_week = week_days[date_obj.weekday()]
print("Active Day of the Week:", active_day_of_week)

# Most active hour of the day
most_active_hour = dataset['Time'].value_counts().idxmax()
print("Most Active Hour of the Day:", most_active_hour)
# Out:
# Most Active Date: 05/12/19
# Active Day of the Week: Thursday
# Most Active Hour of the Day:  1:43 pm

# %%
media_count = dataset[dataset['Text'] == " <media omitted>"].shape[0]
print("Media Count:", media_count)

# Deleted message count
deleted_message_count =dataset[dataset['Text'] == " this message was deleted"].shape[0]
print("Deleted Message Count:", deleted_message_count)

# Missed voice call count
missed_voice_call_count = dataset[dataset['Text'] == " missed voice call"].shape[0]
print("Missed Voice Call Count:", missed_voice_call_count)

# Missed video call count
missed_video_call_count = dataset[dataset['Text'] == " missed video call"].shape[0]
print("Missed Video Call Count:", missed_video_call_count)
# Out:
# Media Count: 0
# Deleted Message Count: 0
# Missed Voice Call Count: 0
# Missed Video Call Count: 0
